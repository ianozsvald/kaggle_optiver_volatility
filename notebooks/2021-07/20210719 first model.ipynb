# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import altair as alt

import dask
import dask.dataframe as dd

ROOT = '/home/ian/data/kaggle/optiver_volatility/'
TRAIN_CSV = os.path.join(ROOT, 'train.csv')

# %%
df_train_all = pd.read_csv(TRAIN_CSV)

# %%
df_train_all.head()
# Out:
#    stock_id  time_id    target
# 0         0        5  0.004136
# 1         0       11  0.001445
# 2         0       16  0.002168
# 3         0       31  0.002195
# 4         0       62  0.001747

# %%
df_train_all.describe()
# Out:
#             stock_id        time_id         target
# count  428932.000000  428932.000000  428932.000000
# mean       62.437944   16038.972721       0.003880
# std        37.126450    9365.103706       0.002936
# min         0.000000       5.000000       0.000105
# 25%        30.000000    7854.000000       0.002026
# 50%        63.000000   15853.000000       0.003048
# 75%        96.000000   23994.000000       0.004738
# max       126.000000   32767.000000       0.070321

# %% [markdown]
# ## What can we learn about the continuous target parameter?

# %% [markdown]
# # Book train
#
# For a stock and time_id we have a list of `seconds_in_bucket` of 100s of items.

# %%
items_in_folder = os.listdir(os.path.join(ROOT, 'book_train.parquet'))
print(f'There are {len(items_in_folder)} items in the folder and they look like {items_in_folder[:5]}')
# Out:
# There are 112 items in the folder and they look like ['stock_id=59', 'stock_id=58', 'stock_id=23', 'stock_id=17', 'stock_id=109']

# %%
df_book_train_stock_0 = pd.read_parquet(os.path.join(ROOT, 'book_train.parquet/stock_id=0'))

# %%
df_book_train_stock_0.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.001422    1.002301     1.00137    1.002353
# 1        5                  1    1.001422    1.002301     1.00137    1.002353
# 2        5                  5    1.001422    1.002301     1.00137    1.002405
# 3        5                  6    1.001422    1.002301     1.00137    1.002405
# 4        5                  7    1.001422    1.002301     1.00137    1.002405
#
#    bid_size1  ask_size1  bid_size2  ask_size2
# 0          3        226          2        100
# 1          3        100          2        100
# 2          3        100          2        100
# 3          3        126          2        100
# 4          3        126          2        100

# %%
df_book_train_stock_0.describe()
# Out:
#              time_id  seconds_in_bucket     bid_price1     ask_price1  \
# count  917553.000000      917553.000000  917553.000000  917553.000000
# mean    15980.056908         293.692015       0.999904       1.000137
# std      9381.778917         173.596440       0.003668       0.003696
# min         5.000000           0.000000       0.938241       0.944337
# 25%      7759.000000         142.000000       0.998368       0.999223
# 50%     15772.000000         292.000000       0.999632       1.000331
# 75%     23834.000000         444.000000       1.000753       1.001560
# max     32767.000000         599.000000       1.045641       1.056892
#
#           bid_price2     ask_price2      bid_size1      ask_size1  \
# count  917553.000000  917553.000000  917553.000000  917553.000000
# mean        0.999864       1.000177     113.717102     100.825350
# std         0.003702       0.003743     108.657209     109.063892
# min         0.937213       0.944456       1.000000       1.000000
# 25%         0.998184       0.999390      22.000000      14.000000
# 50%         0.999472       1.000496     100.000000      93.000000
# 75%         1.000587       1.001745     157.000000     117.000000
# max         1.043756       1.057676    3221.000000   16608.000000
#
#            bid_size2      ask_size2
# count  917553.000000  917553.000000
# mean       86.770241      83.203067
# std        90.602588      94.968388
# min         1.000000       1.000000
# 25%        18.000000      14.000000
# 50%       100.000000      90.000000
# 75%       102.000000     102.000000
# max      4391.000000   16608.000000

# %%
df_book_train_stock_0.query('time_id==5')
# Out:
#      time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 0          5                  0    1.001422    1.002301    1.001370
# 1          5                  1    1.001422    1.002301    1.001370
# 2          5                  5    1.001422    1.002301    1.001370
# 3          5                  6    1.001422    1.002301    1.001370
# 4          5                  7    1.001422    1.002301    1.001370
# ..       ...                ...         ...         ...         ...
# 297        5                585    1.003129    1.003749    1.003025
# 298        5                586    1.003129    1.003749    1.002612
# 299        5                587    1.003129    1.003749    1.003025
# 300        5                588    1.003129    1.003749    1.002612
# 301        5                593    1.003129    1.003749    1.003025
#
#      ask_price2  bid_size1  ask_size1  bid_size2  ask_size2
# 0      1.002353          3        226          2        100
# 1      1.002353          3        100          2        100
# 2      1.002405          3        100          2        100
# 3      1.002405          3        126          2        100
# 4      1.002405          3        126          2        100
# ..          ...        ...        ...        ...        ...
# 297    1.003801        100          3         26          3
# 298    1.003801        100          3          2          3
# 299    1.003801        100          3         26          3
# 300    1.003801        100          3          2          3
# 301    1.003801        100          3         26          3
#
# [302 rows x 10 columns]

# %%
df_book_train_stock_98 = pd.read_parquet(os.path.join(ROOT, 'book_train.parquet/stock_id=98'))

# %%
df_book_train_stock_98.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.000257    1.001263    1.000235    1.001308
# 1        5                  1    1.000235    1.001263    1.000212    1.001308
# 2        5                  4    1.000235    1.001263    1.000212    1.001308
# 3        5                  5    1.000235    1.001263    1.000212    1.001308
# 4        5                  6    1.000235    1.001263    1.000212    1.001308
#
#    bid_size1  ask_size1  bid_size2  ask_size2
# 0          2          1          4          1
# 1          4          1          2          1
# 2          4          1          2          5
# 3          4          1          2         12
# 4          4          1          2          3

# %%
df_book_train_stock_98.describe()
# Out:
#              time_id  seconds_in_bucket     bid_price1     ask_price1  \
# count  905795.000000      905795.000000  905795.000000  905795.000000
# mean    16010.265356         293.448323       0.999934       1.000159
# std      9363.696022         173.897629       0.003392       0.003438
# min         5.000000           0.000000       0.948431       0.955833
# 25%      7837.000000         142.000000       0.998370       0.999310
# 50%     15883.000000         291.000000       0.999603       1.000407
# 75%     23892.000000         444.000000       1.000722       1.001658
# max     32767.000000         599.000000       1.046545       1.051670
#
#           bid_price2     ask_price2      bid_size1      ask_size1  \
# count  905795.000000  905795.000000  905795.000000  905795.000000
# mean        0.999889       1.000196     116.728145      85.488035
# std         0.003450       0.003503     124.206204      95.147750
# min         0.948245       0.955870       1.000000       1.000000
# 25%         0.998175       0.999471      18.000000       7.000000
# 50%         0.999442       1.000563     100.000000      90.000000
# 75%         1.000559       1.001856     160.000000     104.000000
# max         1.046362       1.055001    9497.000000    4300.000000
#
#            bid_size2      ask_size2
# count  905795.000000  905795.000000
# mean       81.129777      66.753292
# std       107.703764      96.254298
# min         1.000000       1.000000
# 25%         6.000000       4.000000
# 50%        78.000000      41.000000
# 75%       100.000000     100.000000
# max      9597.000000    6300.000000

# %%
df_book_train_stock_98.query('time_id==5')
# Out:
#      time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 0          5                  0    1.000257    1.001263    1.000235
# 1          5                  1    1.000235    1.001263    1.000212
# 2          5                  4    1.000235    1.001263    1.000212
# 3          5                  5    1.000235    1.001263    1.000212
# 4          5                  6    1.000235    1.001263    1.000212
# ..       ...                ...         ...         ...         ...
# 256        5                590    0.998715    0.999832    0.998580
# 257        5                591    0.998715    0.999810    0.998580
# 258        5                592    0.998715    0.999273    0.998580
# 259        5                593    0.998580    0.999273    0.997820
# 260        5                595    0.998580    0.999273    0.997820
#
#      ask_price2  bid_size1  ask_size1  bid_size2  ask_size2
# 0      1.001308          2          1          4          1
# 1      1.001308          4          1          2          1
# 2      1.001308          4          1          2          5
# 3      1.001308          4          1          2         12
# 4      1.001308          4          1          2          3
# ..          ...        ...        ...        ...        ...
# 256    1.000145          1          6          7          1
# 257    0.999832         12        100          7          6
# 258    0.999609         11          3          7          1
# 259    0.999609          7          4          1          1
# 260    0.999296          7         13          1          3
#
# [261 rows x 10 columns]

# %% [markdown]
# # Relationship between taret and bid/ask prices?

# %%
#stock_ids = [1, 2, 3]
stock_ids = range(10)

df_train = df_train_all.query('stock_id in @stock_ids')
df_train = df_train.set_index('time_id').drop(columns=['stock_id'])
#df_train.stock_id.value_counts()

# %%
df_book_trains = []
for stock_id in stock_ids:
    print(f"Loading stock_id {stock_id}")
    df_book_train_stock_X = pd.read_parquet(os.path.join(ROOT, f'book_train.parquet/stock_id={stock_id}'))
    df_book_trains.append(df_book_train_stock_X)
    
    
df_book_train = pd.concat(df_book_trains)
df_book_train.shape
# Out:
# Loading stock_id 0
# Loading stock_id 1
# Loading stock_id 2
# Loading stock_id 3
# Loading stock_id 4
# Loading stock_id 5
# Loading stock_id 6
# Loading stock_id 7
# Loading stock_id 8
# Loading stock_id 9
# (12899265, 10)

# %%
df_train.shape, df_book_train.shape
# Out:
# ((38300, 1), (12899265, 10))

# %% [markdown]
# Observations:
#
# * stock id 0 target vs variance of
#   * bid_price1/2  - small positive relationship
#   * ask_price1/2 - small positive relationship
#   * bid_size1/2 - triangular relationship (ie. pos for small values, negative for larger - maybe?)
#   * ask_size1/2 - as for bid size
# * stock id 1 - same checks by eye, looks similar

# %%
new_cols = ['bid_price1', 'bid_price2', 'ask_price1']
new_series = []
for col in new_cols:
    ser_var_on_field = df_book_train.groupby('time_id')[col].var()
    new_col = col + "_var"
    ser_var_on_field.name = new_col
    new_series.append(ser_var_on_field)

# merged on same time_id
df_features = pd.concat(new_series, axis=1)
df_features.head()
# Out:
#          bid_price1_var  bid_price2_var  ask_price1_var
# time_id
# 5              0.000005        0.000005        0.000006
# 11             0.000004        0.000004        0.000004
# 16             0.000003        0.000003        0.000003
# 31             0.000001        0.000001        0.000001
# 62             0.000002        0.000002        0.000002

# %%
df_train_merged = df_train.merge(df_features, left_index=True, right_index=True)
df_train_merged.head()
# Out:
#            target  bid_price1_var  bid_price2_var  ask_price1_var
# time_id
# 5        0.004136        0.000005        0.000005        0.000006
# 5        0.006340        0.000005        0.000005        0.000006
# 5        0.001848        0.000005        0.000005        0.000006
# 5        0.005300        0.000005        0.000005        0.000006
# 5        0.004468        0.000005        0.000005        0.000006

# %%
features = df_train_merged.columns.drop('target')
chs = []
for feature in features:
    print(f"Making {feature}")
    chs.append(alt.Chart(df_train_merged.sample(5_000)).mark_point().encode(x=feature, y='target'))
    
# https://altair-viz.github.io/user_guide/compound_charts.html
alt.vconcat(*chs)
# Out:
# Making bid_price1_var
# Making bid_price2_var
# Making ask_price1_var
# alt.VConcatChart(...)

# %% [markdown]
# # Simplest ML just to get something working
#
# * make train/test split, stratify on `time_id`
# * 3830 rows
#
# **TODO** stratify on time_id between sets

# %%
all_rows = df_train_merged.reset_index()

target = 'target'
cols = features
print(f"Features: {cols}")

all_rows.head()
# Out:
# Features: Index(['bid_price1_var', 'bid_price2_var', 'ask_price1_var'], dtype='object')
#    time_id    target  bid_price1_var  bid_price2_var  ask_price1_var
# 0        5  0.004136        0.000005        0.000005        0.000006
# 1        5  0.006340        0.000005        0.000005        0.000006
# 2        5  0.001848        0.000005        0.000005        0.000006
# 3        5  0.005300        0.000005        0.000005        0.000006
# 4        5  0.004468        0.000005        0.000005        0.000006

# %%
X = all_rows[cols]
y = all_rows[target]
stratify_on = all_rows['time_id']

# %%
# TODO figure out how to stratify on this!
# TODO CHECK I GOT THIS RIGHT!
unique_time_ids = pd.Series(stratify_on.unique()).sample(frac=1.0).values
#unique_time_ids_half = int(unique_time_ids.shape[0] / 2)
#unique_time_ids, unique_time_ids.shape
# TODO make a mask of 0 or 1 if you're in the first half or the second half

# NO, THIS IS WRONG, I NEED TO MAKE A TRAIN SET WITH ALL OF ONE SET OF TIME IDS AND A TEST SET FOR THE OTHER SET,
# NOT ALLOWING THEM TO MIX BETWEEN. There's no information in the time ids so they can occur in either side. For this 
# trivial ML attempt it doesn't matter, but I need to get it right.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
stratify = stratify_on < np.median(unique_time_ids)
stratify
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 38295    False
# 38296    False
# 38297    False
# 38298    False
# 38299    False
# Name: time_id, Length: 38300, dtype: bool

# %%
RANDOM_STATE = 0
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=RANDOM_STATE, stratify=stratify)

# %%
est = LinearRegression()
est = RandomForestRegressor()

# %%
est.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
est.score(X_test, y_test) # r^2
# Out:
# 0.35280535356523546

# %%
#est.coef_
